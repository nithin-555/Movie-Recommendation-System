# %%
import sys
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import yaml
import time
from collections import defaultdict
import gc  # For garbage collection


# !pip install recommenders psutil


print(f"TensorFlow version: {tf.__version__}")


from recommenders.models.deeprec.models.graphrec.lightgcn import LightGCN
original_convert_sp_mat = LightGCN._convert_sp_mat_to_sp_tensor

def patched_convert_sp_mat(self, X):
    """Patch to replace np.mat with proper NumPy 2.0 compatible code"""
    coo = X.tocoo().astype(np.float32)
    indices = np.array([coo.row, coo.col]).transpose()
    return tf.SparseTensor(indices, coo.data, coo.shape)


LightGCN._convert_sp_mat_to_sp_tensor = patched_convert_sp_mat


tf.get_logger().setLevel('ERROR')


from recommenders.utils.timer import Timer
from recommenders.models.deeprec.DataModel.ImplicitCF import ImplicitCF
from recommenders.datasets import movielens
from recommenders.datasets.python_splitters import python_stratified_split
from recommenders.evaluation.python_evaluation import map, ndcg_at_k, precision_at_k, recall_at_k
from recommenders.utils.constants import SEED as DEFAULT_SEED
from recommenders.models.deeprec.deeprec_utils import prepare_hparams
from recommenders.utils.notebook_utils import store_metadata
import psutil
# Out:
# Requirement already satisfied: recommenders in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (5.9.5)
# Requirement already satisfied: category-encoders<3,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (2.8.1)
# Requirement already satisfied: cornac<3,>=1.15.2 in /usr/local/lib/python3.11/dist-packages (from recommenders) (2.3.3)
# Requirement already satisfied: hyperopt<1,>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.2.7)
# Requirement already satisfied: lightgbm<5,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (4.5.0)
# Requirement already satisfied: locust<3,>=2.12.2 in /usr/local/lib/python3.11/dist-packages (from recommenders) (2.37.1)
# Requirement already satisfied: memory-profiler<1,>=0.61.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.61.0)
# Requirement already satisfied: nltk<4,>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from recommenders) (3.9.1)
# Requirement already satisfied: notebook<8,>=6.5.5 in /usr/local/lib/python3.11/dist-packages (from recommenders) (6.5.7)
# Requirement already satisfied: numba<1,>=0.57.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.60.0)
# Requirement already satisfied: pandas<3.0.0,>2.0.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (2.2.2)
# Requirement already satisfied: retrying<2,>=1.3.4 in /usr/local/lib/python3.11/dist-packages (from recommenders) (1.3.4)
# Requirement already satisfied: scikit-learn<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (1.6.1)
# Requirement already satisfied: scikit-surprise>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from recommenders) (1.1.4)
# Requirement already satisfied: seaborn<1,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.13.2)
# Requirement already satisfied: transformers<5,>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (4.51.3)
# Requirement already satisfied: pandera>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.23.1)
# Requirement already satisfied: statsmodels>=0.14.4 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.14.4)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from category-encoders<3,>=2.6.0->recommenders) (2.0.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category-encoders<3,>=2.6.0->recommenders) (1.0.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from category-encoders<3,>=2.6.0->recommenders) (1.15.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from cornac<3,>=1.15.2->recommenders) (4.67.1)
# Requirement already satisfied: powerlaw in /usr/local/lib/python3.11/dist-packages (from cornac<3,>=1.15.2->recommenders) (1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (3.4.2)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (1.0.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (3.1.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (0.10.9.7)
# Requirement already satisfied: configargparse>=1.5.5 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (1.7)
# Requirement already satisfied: flask-cors>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (5.0.1)
# Requirement already satisfied: flask-login>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (0.6.3)
# Requirement already satisfied: flask>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (3.1.0)
# Requirement already satisfied: gevent<25.0.0,>=24.10.1 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (24.11.1)
# Requirement already satisfied: geventhttpclient>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (2.3.3)
# Requirement already satisfied: locust-cloud>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (1.21.3)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (26.4.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (2.32.3)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (75.2.0)
# Requirement already satisfied: werkzeug>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (3.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk<4,>=3.8.1->recommenders) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk<4,>=3.8.1->recommenders) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk<4,>=3.8.1->recommenders) (2024.11.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (6.4.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (5.7.2)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (1.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba<1,>=0.57.0->recommenders) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>2.0.0->recommenders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (24.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.11.4)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.11/dist-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (4.4.2)
# Requirement already satisfied: typing_inspect>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.9.0)
# Requirement already satisfied: hypothesis>=6.92.7 in /usr/local/lib/python3.11/dist-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (6.131.15)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2,>=1.2.0->recommenders) (3.6.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn<1,>=0.13.0->recommenders) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (0.30.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (0.5.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (1.9.0)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.11/dist-packages (from gevent<25.0.0,>=24.10.1->locust<3,>=2.12.2->recommenders) (5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.11/dist-packages (from gevent<25.0.0,>=24.10.1->locust<3,>=2.12.2->recommenders) (7.2)
# Requirement already satisfied: greenlet>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from gevent<25.0.0,>=24.10.1->locust<3,>=2.12.2->recommenders) (3.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (2025.4.26)
# Requirement already satisfied: brotli in /usr/local/lib/python3.11/dist-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (2.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers<5,>=4.27.0->recommenders) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers<5,>=4.27.0->recommenders) (4.13.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (25.3.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->notebook<8,>=6.5.5->recommenders) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.1->notebook<8,>=6.5.5->recommenders) (4.3.7)
# Requirement already satisfied: python-socketio==5.13.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (5.13.0)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (4.12.0)
# Requirement already satisfied: websocket-client>=0.54.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (3.2.3)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook<8,>=6.5.5->recommenders) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook<8,>=6.5.5->recommenders) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (2.19.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook<8,>=6.5.5->recommenders) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook<8,>=6.5.5->recommenders) (4.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->locust<3,>=2.12.2->recommenders) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->locust<3,>=2.12.2->recommenders) (3.10)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->notebook<8,>=6.5.5->recommenders) (0.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing_inspect>=0.6.0->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (1.1.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook<8,>=6.5.5->recommenders) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook<8,>=6.5.5->recommenders) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook<8,>=6.5.5->recommenders) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook<8,>=6.5.5->recommenders) (0.1.7)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.11/dist-packages (from powerlaw->cornac<3,>=1.15.2->recommenders) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook<8,>=6.5.5->recommenders) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook<8,>=6.5.5->recommenders) (1.4.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook<8,>=6.5.5->recommenders) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook<8,>=6.5.5->recommenders) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook<8,>=6.5.5->recommenders) (0.24.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook<8,>=6.5.5->recommenders) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook<8,>=6.5.5->recommenders) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook<8,>=6.5.5->recommenders) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook<8,>=6.5.5->recommenders) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook<8,>=6.5.5->recommenders) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.2.13)
# Requirement already satisfied: simple-websocket>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from python-engineio>=4.11.0->python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook<8,>=6.5.5->recommenders) (1.3.1)
# Requirement already satisfied: wsproto in /usr/local/lib/python3.11/dist-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (1.2.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (0.16.0)
# TensorFlow version: 2.18.0

# %%
from google.colab import drive
drive.mount('/content/drive')


RESULTS_DIR = '/content/drive/MyDrive/lightgcn_results'
os.makedirs(RESULTS_DIR, exist_ok=True)

# Create local directories for model configs and checkpoints
os.makedirs('recommenders/models/deeprec/config', exist_ok=True)
os.makedirs('model_checkpoints', exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
MOVIELENS_DATA_SIZE = '100k'
TOP_K = 10
SEED = DEFAULT_SEED

# Hyperparameters to experiment with
CONFIGS = [
    {'epochs': 50, 'batch_size': 1024, 'name': 'config1'},
    {'epochs': 50, 'batch_size': 256, 'name': 'config2'},
    {'epochs': 100, 'batch_size': 1024, 'name': 'config3'},
    {'epochs': 100, 'batch_size': 256, 'name': 'config4'}
]

def create_yaml_config(config_name, epochs, batch_size):
    """Create YAML config file for LightGCN."""
    yaml_config = {
        'model': {
            'name': 'lightgcn',
            'model_type': 'graphrec',
            'user_embedding_size': 64,
            'item_embedding_size': 64,
            'embed_size': 64,
            'n_layers': 3,
            'batch_size': batch_size,
            'show_step': 1,
            'learning_rate': 0.005,
            'epochs': epochs,
            'eval_epoch': 5,
            'top_k': TOP_K
        },
        'train': {
            'batch_size': batch_size,
            'epochs': epochs,
            'learning_rate': 0.005
        },
        'evaluate': {
            'metrics': ['map', 'ndcg', 'precision', 'recall'],
            'cutoffs': [10, 20],
            'k': 10
        }
    }

    yaml_file_path = f'recommenders/models/deeprec/config/lightgcn_{config_name}.yaml'
    with open(yaml_file_path, 'w') as f:
        yaml.dump(yaml_config, f)

    return yaml_file_path

def calculate_diversity(topk_items, item_popularity):
    """Calculate diversity of recommendations based on item popularity."""
    avg_popularity = np.mean([item_popularity.get(item, 0) for item in topk_items['itemID'].unique()])
    unique_items = len(topk_items['itemID'].unique())
    return {
        'avg_popularity': avg_popularity,
        'unique_items': unique_items
    }

def calculate_popularity_bias(topk_items, item_popularity, top_p=0.2):
    """Calculate popularity bias in recommendations."""
    # Sort items by popularity
    sorted_items = sorted(item_popularity.items(), key=lambda x: x[1], reverse=True)
    # Get top p% popular items
    n_top = int(len(sorted_items) * top_p)
    top_popular = set([item for item, _ in sorted_items[:n_top]])

    # Calculate percentage of recommendations from top popular items
    reco_items = topk_items['itemID'].unique()
    top_popular_in_reco = [item for item in reco_items if item in top_popular]
    popular_ratio = len(top_popular_in_reco) / len(reco_items) if len(reco_items) > 0 else 0

    return {
        'popular_ratio': popular_ratio,
        'top_p_percent': top_p
    }

def reset_tf_graph():
    """Reset TensorFlow graph in a way that works with both TF 1.x and 2.x"""
    if hasattr(tf, 'reset_default_graph'):

        tf.reset_default_graph()
    else:

        tf.compat.v1.reset_default_graph()

# %%
def main():
    # Load data
    print("Loading MovieLens data...")
    df = movielens.load_pandas_df(size=MOVIELENS_DATA_SIZE)
    print("MovieLens data loaded successfully")

    # Calculate item popularity
    item_popularity = df.groupby('itemID').size().to_dict()

    # Split data into train and test
    train, test = python_stratified_split(df, ratio=0.75)
    print(f"Train set size: {len(train)}, Test set size: {len(test)}")

    # Prepare data model once
    data = ImplicitCF(train=train, test=test, seed=SEED)

    # Results dataframe
    results = []

    # For each configuration
    for config in CONFIGS:
        try:
            print(f"\n{'='*50}")
            print(f"Running configuration: {config['name']}")
            print(f"Epochs: {config['epochs']}, Batch Size: {config['batch_size']}")
            print(f"{'='*50}")

            # Create config file
            yaml_file = create_yaml_config(
                config['name'],
                config['epochs'],
                config['batch_size']
            )

            # Prepare hyperparameters
            hparams = prepare_hparams(
                yaml_file,
                n_layers=3,
                batch_size=config['batch_size'],
                epochs=config['epochs'],
                learning_rate=0.005,
                eval_epoch=5,
                top_k=TOP_K,
                decay=0.0001,
                save_epoch=5,
                metrics=['map', 'ndcg', 'precision', 'recall'],
                MODEL_DIR=f"model_checkpoints/{config['name']}"
            )

            # Track memory before training
            memory_before = psutil.Process(os.getpid()).memory_info().rss / 1024 / 1024

            # Initialize model
            model = LightGCN(hparams, data)

            # Train model
            print("Starting model training...")

            with Timer() as train_time:
                model.fit()

            training_time = train_time.interval
            print(f"Training completed in {training_time:.2f} seconds")

            # Track memory after training
            memory_after = psutil.Process(os.getpid()).memory_info().rss / 1024 / 1024
            memory_usage = memory_after - memory_before

            # Prediction time
            with Timer() as pred_time:
                topk_scores = model.recommend_k_items(test, top_k=TOP_K, remove_seen=True)
            prediction_time = pred_time.interval

            # Evaluate model
            eval_map = map(test, topk_scores, k=TOP_K)
            eval_ndcg = ndcg_at_k(test, topk_scores, k=TOP_K)
            eval_precision = precision_at_k(test, topk_scores, k=TOP_K)
            eval_recall = recall_at_k(test, topk_scores, k=TOP_K)

            print("Evaluation Metrics:")
            print(f"MAP@{TOP_K}: {eval_map:.4f}")
            print(f"NDCG@{TOP_K}: {eval_ndcg:.4f}")
            print(f"Precision@{TOP_K}: {eval_precision:.4f}")
            print(f"Recall@{TOP_K}: {eval_recall:.4f}")

            # Calculate diversity metrics
            diversity = calculate_diversity(topk_scores, item_popularity)
            popularity_bias = calculate_popularity_bias(topk_scores, item_popularity)

            # Store results
            result = {
                'config_name': config['name'],
                'epochs': config['epochs'],
                'batch_size': config['batch_size'],
                'map': eval_map,
                'ndcg': eval_ndcg,
                'precision': eval_precision,
                'recall': eval_recall,
                'training_time': training_time,
                'prediction_time': prediction_time,
                'memory_usage_mb': memory_usage,
                'avg_popularity': diversity['avg_popularity'],
                'unique_items': diversity['unique_items'],
                'popular_ratio': popularity_bias['popular_ratio'],
            }

            results.append(result)

            # Save interim results in case of later failure
            if len(results) > 0:
                interim_df = pd.DataFrame(results)
                interim_csv_path = f'{RESULTS_DIR}/lightgcn_evaluation_interim.csv'
                interim_df.to_csv(interim_csv_path, index=False)
                print(f"Interim results saved to '{interim_csv_path}'")

            # Clean up to free memory in Colab
            del model

            # Reset TensorFlow graph for next run
            reset_tf_graph()

            # Force garbage collection
            gc.collect()

        except Exception as e:
            print(f"Error in configuration {config['name']}: {str(e)}")
            # Continue with next configuration
            try:
                reset_tf_graph()
            except:
                print("Failed to reset TensorFlow graph, but continuing anyway.")
            gc.collect()

    # Create results dataframe and save to CSV
    if len(results) > 0:
        results_df = pd.DataFrame(results)
        csv_path = f'{RESULTS_DIR}/lightgcn_evaluation_results.csv'
        results_df.to_csv(csv_path, index=False)
        print(f"\nResults saved to '{csv_path}'")

        # Display summary table
        print("\nSummary of Results:")
        display(results_df[['config_name', 'epochs', 'batch_size', 'map', 'ndcg', 'precision', 'recall', 'training_time']])
    else:
        print("No results were collected. All configurations failed.")

if __name__ == "__main__":
    main()
# Out:
# Loading MovieLens data...
# 100%|██████████| 4.81k/4.81k [00:00<00:00, 12.0kKB/s]
# MovieLens data loaded successfully
# Train set size: 74992, Test set size: 25008
#
# ==================================================
# Running configuration: config1
# Epochs: 50, Batch Size: 1024
# ==================================================
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.
# Starting model training...
# Epoch 1 (train)4.2s: train loss = 0.47168 = (mf)0.47143 + (embed)0.00024
# Epoch 2 (train)5.3s: train loss = 0.29010 = (mf)0.28947 + (embed)0.00063
# Epoch 3 (train)5.3s: train loss = 0.25365 = (mf)0.25286 + (embed)0.00079
# Epoch 4 (train)3.2s: train loss = 0.23849 = (mf)0.23752 + (embed)0.00097
# Save model to path /content/model_checkpoints/config1/epoch_5
# Epoch 5 (train)2.2s + (eval)0.4s: train loss = 0.22635 = (mf)0.22525 + (embed)0.00111, map = 0.21589, ndcg = 0.34528, precision = 0.29873, recall = 0.15604
# Epoch 6 (train)3.1s: train loss = 0.21993 = (mf)0.21872 + (embed)0.00122
# Epoch 7 (train)2.0s: train loss = 0.21247 = (mf)0.21115 + (embed)0.00133
# Epoch 8 (train)2.0s: train loss = 0.20166 = (mf)0.20020 + (embed)0.00146
# Epoch 9 (train)2.0s: train loss = 0.18961 = (mf)0.18799 + (embed)0.00162
# Save model to path /content/model_checkpoints/config1/epoch_10
# Epoch 10 (train)2.0s + (eval)0.5s: train loss = 0.18167 = (mf)0.17989 + (embed)0.00179, map = 0.25166, ndcg = 0.38822, precision = 0.33934, recall = 0.17587
# Epoch 11 (train)2.4s: train loss = 0.17129 = (mf)0.16935 + (embed)0.00194
# Epoch 12 (train)3.2s: train loss = 0.16968 = (mf)0.16759 + (embed)0.00209
# Epoch 13 (train)2.0s: train loss = 0.16617 = (mf)0.16396 + (embed)0.00221
# Epoch 14 (train)2.0s: train loss = 0.16545 = (mf)0.16313 + (embed)0.00232
# Save model to path /content/model_checkpoints/config1/epoch_15
# Epoch 15 (train)2.0s + (eval)0.3s: train loss = 0.16116 = (mf)0.15875 + (embed)0.00241, map = 0.26510, ndcg = 0.40379, precision = 0.35090, recall = 0.18458
# Epoch 16 (train)2.0s: train loss = 0.16134 = (mf)0.15882 + (embed)0.00251
# Epoch 17 (train)2.2s: train loss = 0.15985 = (mf)0.15725 + (embed)0.00260
# Epoch 18 (train)3.1s: train loss = 0.15368 = (mf)0.15099 + (embed)0.00269
# Epoch 19 (train)2.1s: train loss = 0.15133 = (mf)0.14853 + (embed)0.00280
# Save model to path /content/model_checkpoints/config1/epoch_20
# Epoch 20 (train)2.0s + (eval)0.2s: train loss = 0.15087 = (mf)0.14798 + (embed)0.00288, map = 0.27083, ndcg = 0.41081, precision = 0.35737, recall = 0.18917
# Epoch 21 (train)2.0s: train loss = 0.14900 = (mf)0.14603 + (embed)0.00298
# Epoch 22 (train)2.0s: train loss = 0.14541 = (mf)0.14232 + (embed)0.00309
# Epoch 23 (train)2.1s: train loss = 0.14408 = (mf)0.14089 + (embed)0.00320
# Epoch 24 (train)3.1s: train loss = 0.13858 = (mf)0.13528 + (embed)0.00330
# Save model to path /content/model_checkpoints/config1/epoch_25
# Epoch 25 (train)2.3s + (eval)0.5s: train loss = 0.13870 = (mf)0.13528 + (embed)0.00342, map = 0.28242, ndcg = 0.42342, precision = 0.36978, recall = 0.19689
# Epoch 26 (train)2.0s: train loss = 0.13670 = (mf)0.13317 + (embed)0.00354
# Epoch 27 (train)2.0s: train loss = 0.13430 = (mf)0.13065 + (embed)0.00365
# Epoch 28 (train)2.0s: train loss = 0.13218 = (mf)0.12842 + (embed)0.00376
# Epoch 29 (train)2.1s: train loss = 0.13249 = (mf)0.12863 + (embed)0.00386
# Save model to path /content/model_checkpoints/config1/epoch_30
# Epoch 30 (train)3.1s + (eval)0.4s: train loss = 0.12881 = (mf)0.12482 + (embed)0.00399, map = 0.29477, ndcg = 0.43656, precision = 0.37985, recall = 0.20238
# Epoch 31 (train)2.2s: train loss = 0.12755 = (mf)0.12346 + (embed)0.00409
# Epoch 32 (train)2.0s: train loss = 0.12605 = (mf)0.12183 + (embed)0.00422
# Epoch 33 (train)2.0s: train loss = 0.12559 = (mf)0.12126 + (embed)0.00433
# Epoch 34 (train)2.0s: train loss = 0.12141 = (mf)0.11696 + (embed)0.00445
# Save model to path /content/model_checkpoints/config1/epoch_35
# Epoch 35 (train)2.0s + (eval)0.7s: train loss = 0.12109 = (mf)0.11653 + (embed)0.00457, map = 0.29790, ndcg = 0.43974, precision = 0.38420, recall = 0.20451
# Epoch 36 (train)3.1s: train loss = 0.11732 = (mf)0.11263 + (embed)0.00469
# Epoch 37 (train)2.2s: train loss = 0.11915 = (mf)0.11435 + (embed)0.00480
# Epoch 38 (train)2.0s: train loss = 0.11773 = (mf)0.11282 + (embed)0.00492
# Epoch 39 (train)2.0s: train loss = 0.11122 = (mf)0.10616 + (embed)0.00506
# Save model to path /content/model_checkpoints/config1/epoch_40
# Epoch 40 (train)2.0s + (eval)0.2s: train loss = 0.11425 = (mf)0.10907 + (embed)0.00518, map = 0.30428, ndcg = 0.44706, precision = 0.38929, recall = 0.20962
# Epoch 41 (train)2.1s: train loss = 0.11097 = (mf)0.10567 + (embed)0.00530
# Epoch 42 (train)3.2s: train loss = 0.10831 = (mf)0.10287 + (embed)0.00544
# Epoch 43 (train)2.3s: train loss = 0.10932 = (mf)0.10376 + (embed)0.00555
# Epoch 44 (train)2.1s: train loss = 0.10470 = (mf)0.09902 + (embed)0.00568
# Save model to path /content/model_checkpoints/config1/epoch_45
# Epoch 45 (train)2.6s + (eval)0.5s: train loss = 0.10536 = (mf)0.09955 + (embed)0.00581, map = 0.30951, ndcg = 0.45333, precision = 0.39406, recall = 0.21075
# Epoch 46 (train)2.0s: train loss = 0.10619 = (mf)0.10026 + (embed)0.00593
# Epoch 47 (train)2.4s: train loss = 0.10427 = (mf)0.09821 + (embed)0.00605
# Epoch 48 (train)3.1s: train loss = 0.10272 = (mf)0.09654 + (embed)0.00618
# Epoch 49 (train)2.0s: train loss = 0.09851 = (mf)0.09219 + (embed)0.00632
# Save model to path /content/model_checkpoints/config1/epoch_50
# Epoch 50 (train)2.0s + (eval)0.3s: train loss = 0.09715 = (mf)0.09070 + (embed)0.00645, map = 0.31335, ndcg = 0.45835, precision = 0.39958, recall = 0.21631
# Training completed in 127.12 seconds
# Evaluation Metrics:
# MAP@10: 0.1396
# NDCG@10: 0.4584
# Precision@10: 0.3996
# Recall@10: 0.2163
# Interim results saved to '/content/drive/MyDrive/lightgcn_results/lightgcn_evaluation_interim.csv'
#
# ==================================================
# Running configuration: config2
# Epochs: 50, Batch Size: 256
# ==================================================
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.
# Starting model training...
# Epoch 1 (train)8.0s: train loss = 0.34148 = (mf)0.34094 + (embed)0.00054
# Epoch 2 (train)6.4s: train loss = 0.23233 = (mf)0.23131 + (embed)0.00102
# Epoch 3 (train)7.8s: train loss = 0.21574 = (mf)0.21443 + (embed)0.00131
# Epoch 4 (train)6.4s: train loss = 0.19462 = (mf)0.19303 + (embed)0.00160
# Save model to path /content/model_checkpoints/config2/epoch_5
# Epoch 5 (train)9.0s + (eval)0.3s: train loss = 0.17808 = (mf)0.17616 + (embed)0.00192, map = 0.25005, ndcg = 0.38852, precision = 0.33839, recall = 0.17750
# Epoch 6 (train)6.4s: train loss = 0.17035 = (mf)0.16815 + (embed)0.00220
# Epoch 7 (train)7.9s: train loss = 0.16650 = (mf)0.16408 + (embed)0.00242
# Epoch 8 (train)6.5s: train loss = 0.16089 = (mf)0.15826 + (embed)0.00263
# Epoch 9 (train)7.8s: train loss = 0.15860 = (mf)0.15579 + (embed)0.00281
# Save model to path /content/model_checkpoints/config2/epoch_10
# Epoch 10 (train)6.4s + (eval)0.6s: train loss = 0.15098 = (mf)0.14796 + (embed)0.00302, map = 0.26873, ndcg = 0.40867, precision = 0.35843, recall = 0.19074
# Epoch 11 (train)7.8s: train loss = 0.14780 = (mf)0.14457 + (embed)0.00324
# Epoch 12 (train)6.4s: train loss = 0.14335 = (mf)0.13989 + (embed)0.00346
# Epoch 13 (train)7.8s: train loss = 0.13749 = (mf)0.13378 + (embed)0.00371
# Epoch 14 (train)7.9s: train loss = 0.13700 = (mf)0.13307 + (embed)0.00393
# Save model to path /content/model_checkpoints/config2/epoch_15
# Epoch 15 (train)7.8s + (eval)0.3s: train loss = 0.12957 = (mf)0.12540 + (embed)0.00417, map = 0.29106, ndcg = 0.43255, precision = 0.37635, recall = 0.20014
# Epoch 16 (train)6.6s: train loss = 0.12830 = (mf)0.12388 + (embed)0.00442
# Epoch 17 (train)7.4s: train loss = 0.12469 = (mf)0.12004 + (embed)0.00466
# Epoch 18 (train)6.6s: train loss = 0.12122 = (mf)0.11631 + (embed)0.00491
# Epoch 19 (train)7.4s: train loss = 0.11737 = (mf)0.11222 + (embed)0.00515
# Save model to path /content/model_checkpoints/config2/epoch_20
# Epoch 20 (train)6.6s + (eval)0.8s: train loss = 0.11563 = (mf)0.11022 + (embed)0.00542, map = 0.30504, ndcg = 0.44670, precision = 0.38855, recall = 0.20623
# Epoch 21 (train)7.1s: train loss = 0.11187 = (mf)0.10620 + (embed)0.00567
# Epoch 22 (train)7.0s: train loss = 0.10970 = (mf)0.10377 + (embed)0.00593
# Epoch 23 (train)7.1s: train loss = 0.10736 = (mf)0.10116 + (embed)0.00619
# Epoch 24 (train)7.1s: train loss = 0.10317 = (mf)0.09674 + (embed)0.00644
# Save model to path /content/model_checkpoints/config2/epoch_25
# Epoch 25 (train)6.9s + (eval)0.3s: train loss = 0.10036 = (mf)0.09369 + (embed)0.00667, map = 0.31052, ndcg = 0.45247, precision = 0.39809, recall = 0.21219
# Epoch 26 (train)7.2s: train loss = 0.09999 = (mf)0.09307 + (embed)0.00692
# Epoch 27 (train)6.8s: train loss = 0.09686 = (mf)0.08969 + (embed)0.00717
# Epoch 28 (train)7.3s: train loss = 0.09522 = (mf)0.08781 + (embed)0.00741
# Epoch 29 (train)6.7s: train loss = 0.09368 = (mf)0.08602 + (embed)0.00766
# Save model to path /content/model_checkpoints/config2/epoch_30
# Epoch 30 (train)7.3s + (eval)0.8s: train loss = 0.09053 = (mf)0.08265 + (embed)0.00789, map = 0.30884, ndcg = 0.45147, precision = 0.39480, recall = 0.21162
# Epoch 31 (train)6.4s: train loss = 0.08953 = (mf)0.08140 + (embed)0.00814
# Epoch 32 (train)7.6s: train loss = 0.08932 = (mf)0.08094 + (embed)0.00838
# Epoch 33 (train)6.3s: train loss = 0.08564 = (mf)0.07703 + (embed)0.00862
# Epoch 34 (train)7.6s: train loss = 0.08442 = (mf)0.07558 + (embed)0.00884
# Save model to path /content/model_checkpoints/config2/epoch_35
# Epoch 35 (train)6.4s + (eval)0.3s: train loss = 0.08123 = (mf)0.07214 + (embed)0.00909, map = 0.30710, ndcg = 0.45017, precision = 0.39258, recall = 0.21050
# Epoch 36 (train)7.6s: train loss = 0.08328 = (mf)0.07397 + (embed)0.00931
# Epoch 37 (train)6.4s: train loss = 0.08203 = (mf)0.07250 + (embed)0.00954
# Epoch 38 (train)7.6s: train loss = 0.07897 = (mf)0.06921 + (embed)0.00976
# Epoch 39 (train)6.4s: train loss = 0.07919 = (mf)0.06923 + (embed)0.00996
# Save model to path /content/model_checkpoints/config2/epoch_40
# Epoch 40 (train)7.7s + (eval)0.6s: train loss = 0.07519 = (mf)0.06498 + (embed)0.01021, map = 0.30196, ndcg = 0.44475, precision = 0.39056, recall = 0.21092
# Epoch 41 (train)6.3s: train loss = 0.07657 = (mf)0.06617 + (embed)0.01040
# Epoch 42 (train)7.6s: train loss = 0.07348 = (mf)0.06286 + (embed)0.01062
# Epoch 43 (train)6.3s: train loss = 0.07405 = (mf)0.06322 + (embed)0.01083
# Epoch 44 (train)8.1s: train loss = 0.07199 = (mf)0.06094 + (embed)0.01104
# Save model to path /content/model_checkpoints/config2/epoch_45
# Epoch 45 (train)7.2s + (eval)0.3s: train loss = 0.07018 = (mf)0.05894 + (embed)0.01124, map = 0.30012, ndcg = 0.44247, precision = 0.38823, recall = 0.20856
# Epoch 46 (train)7.6s: train loss = 0.07059 = (mf)0.05914 + (embed)0.01145
# Epoch 47 (train)6.4s: train loss = 0.06800 = (mf)0.05636 + (embed)0.01164
# Epoch 48 (train)7.7s: train loss = 0.06881 = (mf)0.05701 + (embed)0.01180
# Epoch 49 (train)6.4s: train loss = 0.06735 = (mf)0.05533 + (embed)0.01202
# Save model to path /content/model_checkpoints/config2/epoch_50
# Epoch 50 (train)7.6s + (eval)0.6s: train loss = 0.06625 = (mf)0.05405 + (embed)0.01220, map = 0.29009, ndcg = 0.43386, precision = 0.37964, recall = 0.20801
# Training completed in 361.85 seconds
# Evaluation Metrics:
# MAP@10: 0.1299
# NDCG@10: 0.4339
# Precision@10: 0.3796
# Recall@10: 0.2080
# Interim results saved to '/content/drive/MyDrive/lightgcn_results/lightgcn_evaluation_interim.csv'
#
# ==================================================
# Running configuration: config3
# Epochs: 100, Batch Size: 1024
# ==================================================
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.
# Starting model training...
# Epoch 1 (train)2.2s: train loss = 0.47283 = (mf)0.47258 + (embed)0.00024
# Epoch 2 (train)2.0s: train loss = 0.28289 = (mf)0.28224 + (embed)0.00065
# Epoch 3 (train)3.0s: train loss = 0.24941 = (mf)0.24858 + (embed)0.00083
# Epoch 4 (train)2.4s: train loss = 0.23783 = (mf)0.23684 + (embed)0.00099
# Save model to path /content/model_checkpoints/config3/epoch_5
# Epoch 5 (train)2.0s + (eval)0.3s: train loss = 0.22916 = (mf)0.22805 + (embed)0.00111, map = 0.21836, ndcg = 0.34906, precision = 0.30117, recall = 0.15673
# Epoch 6 (train)2.0s: train loss = 0.21538 = (mf)0.21415 + (embed)0.00123
# Epoch 7 (train)2.0s: train loss = 0.20722 = (mf)0.20587 + (embed)0.00136
# Epoch 8 (train)2.0s: train loss = 0.19574 = (mf)0.19424 + (embed)0.00149
# Epoch 9 (train)3.0s: train loss = 0.18845 = (mf)0.18682 + (embed)0.00163
# Save model to path /content/model_checkpoints/config3/epoch_10
# Epoch 10 (train)2.4s + (eval)0.5s: train loss = 0.18166 = (mf)0.17988 + (embed)0.00178, map = 0.25151, ndcg = 0.38928, precision = 0.34008, recall = 0.17924
# Epoch 11 (train)2.0s: train loss = 0.17143 = (mf)0.16952 + (embed)0.00191
# Epoch 12 (train)2.0s: train loss = 0.17157 = (mf)0.16954 + (embed)0.00203
# Epoch 13 (train)2.0s: train loss = 0.16767 = (mf)0.16552 + (embed)0.00215
# Epoch 14 (train)2.0s: train loss = 0.16698 = (mf)0.16472 + (embed)0.00226
# Save model to path /content/model_checkpoints/config3/epoch_15
# Epoch 15 (train)3.1s + (eval)0.4s: train loss = 0.16472 = (mf)0.16237 + (embed)0.00234, map = 0.26154, ndcg = 0.40196, precision = 0.35345, recall = 0.18817
# Epoch 16 (train)2.1s: train loss = 0.16244 = (mf)0.15999 + (embed)0.00244
# Epoch 17 (train)2.0s: train loss = 0.15818 = (mf)0.15565 + (embed)0.00253
# Epoch 18 (train)2.0s: train loss = 0.15378 = (mf)0.15115 + (embed)0.00263
# Epoch 19 (train)2.0s: train loss = 0.15378 = (mf)0.15106 + (embed)0.00272
# Save model to path /content/model_checkpoints/config3/epoch_20
# Epoch 20 (train)2.0s + (eval)0.7s: train loss = 0.15196 = (mf)0.14914 + (embed)0.00282, map = 0.26903, ndcg = 0.40928, precision = 0.35907, recall = 0.19249
# Epoch 21 (train)3.1s: train loss = 0.14832 = (mf)0.14540 + (embed)0.00292
# Epoch 22 (train)2.0s: train loss = 0.14902 = (mf)0.14600 + (embed)0.00302
# Epoch 23 (train)2.0s: train loss = 0.14310 = (mf)0.13998 + (embed)0.00313
# Epoch 24 (train)2.0s: train loss = 0.14115 = (mf)0.13791 + (embed)0.00324
# Save model to path /content/model_checkpoints/config3/epoch_25
# Epoch 25 (train)2.0s + (eval)0.2s: train loss = 0.13928 = (mf)0.13592 + (embed)0.00336, map = 0.28445, ndcg = 0.42601, precision = 0.37179, recall = 0.19866
# Epoch 26 (train)2.2s: train loss = 0.13632 = (mf)0.13285 + (embed)0.00347
# Epoch 27 (train)3.1s: train loss = 0.13581 = (mf)0.13222 + (embed)0.00359
# Epoch 28 (train)2.1s: train loss = 0.13415 = (mf)0.13044 + (embed)0.00371
# Epoch 29 (train)2.0s: train loss = 0.13195 = (mf)0.12812 + (embed)0.00383
# Save model to path /content/model_checkpoints/config3/epoch_30
# Epoch 30 (train)2.0s + (eval)0.5s: train loss = 0.12845 = (mf)0.12449 + (embed)0.00396, map = 0.29264, ndcg = 0.43530, precision = 0.37762, recall = 0.20257
# Epoch 31 (train)2.0s: train loss = 0.12699 = (mf)0.12292 + (embed)0.00407
# Epoch 32 (train)2.3s: train loss = 0.12436 = (mf)0.12016 + (embed)0.00420
# Epoch 33 (train)3.2s: train loss = 0.12195 = (mf)0.11762 + (embed)0.00433
# Epoch 34 (train)2.0s: train loss = 0.12289 = (mf)0.11842 + (embed)0.00446
# Save model to path /content/model_checkpoints/config3/epoch_35
# Epoch 35 (train)2.0s + (eval)0.3s: train loss = 0.12001 = (mf)0.11543 + (embed)0.00458, map = 0.30671, ndcg = 0.44894, precision = 0.38961, recall = 0.20966
# Epoch 36 (train)2.0s: train loss = 0.12039 = (mf)0.11569 + (embed)0.00469
# Epoch 37 (train)2.0s: train loss = 0.11710 = (mf)0.11229 + (embed)0.00481
# Epoch 38 (train)2.1s: train loss = 0.11589 = (mf)0.11096 + (embed)0.00494
# Epoch 39 (train)3.1s: train loss = 0.11109 = (mf)0.10601 + (embed)0.00507
# Save model to path /content/model_checkpoints/config3/epoch_40
# Epoch 40 (train)2.1s + (eval)0.5s: train loss = 0.11158 = (mf)0.10638 + (embed)0.00520, map = 0.31518, ndcg = 0.45861, precision = 0.39777, recall = 0.21368
# Epoch 41 (train)2.0s: train loss = 0.10988 = (mf)0.10454 + (embed)0.00534
# Epoch 42 (train)2.0s: train loss = 0.10991 = (mf)0.10444 + (embed)0.00547
# Epoch 43 (train)2.0s: train loss = 0.10807 = (mf)0.10248 + (embed)0.00559
# Epoch 44 (train)2.3s: train loss = 0.10638 = (mf)0.10066 + (embed)0.00572
# Save model to path /content/model_checkpoints/config3/epoch_45
# Epoch 45 (train)3.1s + (eval)0.2s: train loss = 0.10701 = (mf)0.10117 + (embed)0.00584, map = 0.31562, ndcg = 0.45863, precision = 0.39873, recall = 0.21468
# Epoch 46 (train)2.0s: train loss = 0.10110 = (mf)0.09511 + (embed)0.00598
# Epoch 47 (train)2.0s: train loss = 0.10002 = (mf)0.09390 + (embed)0.00612
# Epoch 48 (train)2.0s: train loss = 0.10263 = (mf)0.09639 + (embed)0.00624
# Epoch 49 (train)2.0s: train loss = 0.09921 = (mf)0.09284 + (embed)0.00638
# Save model to path /content/model_checkpoints/config3/epoch_50
# Epoch 50 (train)2.2s + (eval)0.7s: train loss = 0.09908 = (mf)0.09259 + (embed)0.00649, map = 0.31858, ndcg = 0.46207, precision = 0.40361, recall = 0.21894
# Epoch 51 (train)2.9s: train loss = 0.09741 = (mf)0.09078 + (embed)0.00663
# Epoch 52 (train)2.0s: train loss = 0.09573 = (mf)0.08896 + (embed)0.00676
# Epoch 53 (train)2.0s: train loss = 0.09618 = (mf)0.08931 + (embed)0.00688
# Epoch 54 (train)2.0s: train loss = 0.09392 = (mf)0.08692 + (embed)0.00700
# Save model to path /content/model_checkpoints/config3/epoch_55
# Epoch 55 (train)2.0s + (eval)0.2s: train loss = 0.09185 = (mf)0.08470 + (embed)0.00714, map = 0.31609, ndcg = 0.46009, precision = 0.40477, recall = 0.21858
# Epoch 56 (train)2.4s: train loss = 0.09011 = (mf)0.08283 + (embed)0.00727
# Epoch 57 (train)3.0s: train loss = 0.09037 = (mf)0.08298 + (embed)0.00739
# Epoch 58 (train)2.0s: train loss = 0.08960 = (mf)0.08208 + (embed)0.00752
# Epoch 59 (train)2.0s: train loss = 0.08878 = (mf)0.08112 + (embed)0.00766
# Save model to path /content/model_checkpoints/config3/epoch_60
# Epoch 60 (train)2.0s + (eval)0.5s: train loss = 0.08920 = (mf)0.08142 + (embed)0.00778, map = 0.31238, ndcg = 0.45490, precision = 0.40021, recall = 0.21593
# Epoch 61 (train)2.0s: train loss = 0.08747 = (mf)0.07958 + (embed)0.00789
# Epoch 62 (train)2.5s: train loss = 0.08459 = (mf)0.07657 + (embed)0.00803
# Epoch 63 (train)2.9s: train loss = 0.08630 = (mf)0.07816 + (embed)0.00814
# Epoch 64 (train)2.0s: train loss = 0.08526 = (mf)0.07698 + (embed)0.00827
# Save model to path /content/model_checkpoints/config3/epoch_65
# Epoch 65 (train)2.0s + (eval)0.2s: train loss = 0.08591 = (mf)0.07753 + (embed)0.00838, map = 0.31335, ndcg = 0.45622, precision = 0.40117, recall = 0.21665
# Epoch 66 (train)2.0s: train loss = 0.08159 = (mf)0.07309 + (embed)0.00850
# Epoch 67 (train)2.0s: train loss = 0.08206 = (mf)0.07345 + (embed)0.00861
# Epoch 68 (train)2.5s: train loss = 0.08195 = (mf)0.07322 + (embed)0.00873
# Epoch 69 (train)2.9s: train loss = 0.07928 = (mf)0.07041 + (embed)0.00887
# Save model to path /content/model_checkpoints/config3/epoch_70
# Epoch 70 (train)2.0s + (eval)0.5s: train loss = 0.07950 = (mf)0.07051 + (embed)0.00899, map = 0.30984, ndcg = 0.45342, precision = 0.39862, recall = 0.21578
# Epoch 71 (train)2.0s: train loss = 0.07895 = (mf)0.06986 + (embed)0.00909
# Epoch 72 (train)2.0s: train loss = 0.07694 = (mf)0.06773 + (embed)0.00922
# Epoch 73 (train)2.0s: train loss = 0.07817 = (mf)0.06882 + (embed)0.00935
# Epoch 74 (train)3.7s: train loss = 0.07703 = (mf)0.06758 + (embed)0.00945
# Save model to path /content/model_checkpoints/config3/epoch_75
# Epoch 75 (train)3.4s + (eval)0.2s: train loss = 0.07483 = (mf)0.06526 + (embed)0.00956, map = 0.30761, ndcg = 0.45215, precision = 0.39703, recall = 0.21555
# Epoch 76 (train)2.0s: train loss = 0.07503 = (mf)0.06534 + (embed)0.00969
# Epoch 77 (train)2.0s: train loss = 0.07421 = (mf)0.06443 + (embed)0.00978
# Epoch 78 (train)2.0s: train loss = 0.07432 = (mf)0.06444 + (embed)0.00988
# Epoch 79 (train)2.0s: train loss = 0.07327 = (mf)0.06328 + (embed)0.00999
# Save model to path /content/model_checkpoints/config3/epoch_80
# Epoch 80 (train)2.4s + (eval)0.7s: train loss = 0.07431 = (mf)0.06421 + (embed)0.01010, map = 0.30637, ndcg = 0.45039, precision = 0.39629, recall = 0.21472
# Epoch 81 (train)2.7s: train loss = 0.07228 = (mf)0.06209 + (embed)0.01020
# Epoch 82 (train)2.0s: train loss = 0.07136 = (mf)0.06106 + (embed)0.01031
# Epoch 83 (train)2.0s: train loss = 0.07118 = (mf)0.06076 + (embed)0.01042
# Epoch 84 (train)2.0s: train loss = 0.07062 = (mf)0.06009 + (embed)0.01053
# Save model to path /content/model_checkpoints/config3/epoch_85
# Epoch 85 (train)2.0s + (eval)0.2s: train loss = 0.07109 = (mf)0.06047 + (embed)0.01062, map = 0.30513, ndcg = 0.44866, precision = 0.39353, recall = 0.21277
# Epoch 86 (train)2.6s: train loss = 0.06962 = (mf)0.05891 + (embed)0.01072
# Epoch 87 (train)2.7s: train loss = 0.07024 = (mf)0.05942 + (embed)0.01082
# Epoch 88 (train)2.0s: train loss = 0.06786 = (mf)0.05693 + (embed)0.01093
# Epoch 89 (train)2.0s: train loss = 0.06849 = (mf)0.05746 + (embed)0.01103
# Save model to path /content/model_checkpoints/config3/epoch_90
# Epoch 90 (train)2.0s + (eval)0.5s: train loss = 0.06710 = (mf)0.05597 + (embed)0.01113, map = 0.30227, ndcg = 0.44614, precision = 0.39290, recall = 0.21378
# Epoch 91 (train)2.0s: train loss = 0.06701 = (mf)0.05579 + (embed)0.01122
# Epoch 92 (train)2.7s: train loss = 0.06749 = (mf)0.05618 + (embed)0.01131
# Epoch 93 (train)2.6s: train loss = 0.06746 = (mf)0.05603 + (embed)0.01143
# Epoch 94 (train)2.0s: train loss = 0.06424 = (mf)0.05271 + (embed)0.01153
# Save model to path /content/model_checkpoints/config3/epoch_95
# Epoch 95 (train)2.0s + (eval)0.3s: train loss = 0.06585 = (mf)0.05425 + (embed)0.01161, map = 0.29911, ndcg = 0.44221, precision = 0.38834, recall = 0.20950
# Epoch 96 (train)2.0s: train loss = 0.06465 = (mf)0.05295 + (embed)0.01171
# Epoch 97 (train)2.0s: train loss = 0.06547 = (mf)0.05366 + (embed)0.01180
# Epoch 98 (train)2.7s: train loss = 0.06469 = (mf)0.05279 + (embed)0.01190
# Epoch 99 (train)2.7s: train loss = 0.06503 = (mf)0.05306 + (embed)0.01196
# Save model to path /content/model_checkpoints/config3/epoch_100
# Epoch 100 (train)2.0s + (eval)0.3s: train loss = 0.06448 = (mf)0.05242 + (embed)0.01206, map = 0.29134, ndcg = 0.43667, precision = 0.38568, recall = 0.20966
# Training completed in 233.89 seconds
# Evaluation Metrics:
# MAP@10: 0.1304
# NDCG@10: 0.4367
# Precision@10: 0.3857
# Recall@10: 0.2097
# Interim results saved to '/content/drive/MyDrive/lightgcn_results/lightgcn_evaluation_interim.csv'
#
# ==================================================
# Running configuration: config4
# Epochs: 100, Batch Size: 256
# ==================================================
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.
# Starting model training...
# Epoch 1 (train)7.2s: train loss = 0.33147 = (mf)0.33090 + (embed)0.00057
# Epoch 2 (train)6.9s: train loss = 0.23448 = (mf)0.23343 + (embed)0.00105
# Epoch 3 (train)7.1s: train loss = 0.21923 = (mf)0.21794 + (embed)0.00129
# Epoch 4 (train)6.9s: train loss = 0.20121 = (mf)0.19965 + (embed)0.00156
# Save model to path /content/model_checkpoints/config4/epoch_5
# Epoch 5 (train)7.1s + (eval)0.5s: train loss = 0.18229 = (mf)0.18042 + (embed)0.00187, map = 0.25055, ndcg = 0.38721, precision = 0.33849, recall = 0.17780
# Epoch 6 (train)6.7s: train loss = 0.17314 = (mf)0.17098 + (embed)0.00217
# Epoch 7 (train)7.5s: train loss = 0.16661 = (mf)0.16420 + (embed)0.00241
# Epoch 8 (train)6.6s: train loss = 0.16385 = (mf)0.16123 + (embed)0.00262
# Epoch 9 (train)7.4s: train loss = 0.15519 = (mf)0.15237 + (embed)0.00283
# Save model to path /content/model_checkpoints/config4/epoch_10
# Epoch 10 (train)6.6s + (eval)0.5s: train loss = 0.15031 = (mf)0.14726 + (embed)0.00304, map = 0.27399, ndcg = 0.41513, precision = 0.36172, recall = 0.19529
# Epoch 11 (train)7.7s: train loss = 0.14956 = (mf)0.14632 + (embed)0.00324
# Epoch 12 (train)6.4s: train loss = 0.14388 = (mf)0.14042 + (embed)0.00346
# Epoch 13 (train)7.7s: train loss = 0.13791 = (mf)0.13422 + (embed)0.00369
# Epoch 14 (train)6.4s: train loss = 0.13567 = (mf)0.13175 + (embed)0.00392
# Save model to path /content/model_checkpoints/config4/epoch_15
# Epoch 15 (train)7.7s + (eval)0.3s: train loss = 0.13128 = (mf)0.12713 + (embed)0.00415, map = 0.28594, ndcg = 0.42926, precision = 0.37688, recall = 0.20284
# Epoch 16 (train)6.4s: train loss = 0.12796 = (mf)0.12355 + (embed)0.00441
# Epoch 17 (train)9.6s: train loss = 0.12626 = (mf)0.12161 + (embed)0.00464
# Epoch 18 (train)7.6s: train loss = 0.11958 = (mf)0.11469 + (embed)0.00489
# Epoch 19 (train)7.7s: train loss = 0.11770 = (mf)0.11257 + (embed)0.00513
# Save model to path /content/model_checkpoints/config4/epoch_20
# Epoch 20 (train)6.4s + (eval)0.6s: train loss = 0.11428 = (mf)0.10890 + (embed)0.00538, map = 0.29482, ndcg = 0.43931, precision = 0.38388, recall = 0.20826
# Epoch 21 (train)9.2s: train loss = 0.11139 = (mf)0.10575 + (embed)0.00564
# Epoch 22 (train)6.4s: train loss = 0.11059 = (mf)0.10470 + (embed)0.00589
# Epoch 23 (train)7.7s: train loss = 0.10507 = (mf)0.09893 + (embed)0.00614
# Epoch 24 (train)6.4s: train loss = 0.10417 = (mf)0.09778 + (embed)0.00640
# Save model to path /content/model_checkpoints/config4/epoch_25
# Epoch 25 (train)7.7s + (eval)0.3s: train loss = 0.10033 = (mf)0.09367 + (embed)0.00667, map = 0.30872, ndcg = 0.45360, precision = 0.39268, recall = 0.21379
# Epoch 26 (train)6.4s: train loss = 0.09978 = (mf)0.09287 + (embed)0.00691
# Epoch 27 (train)7.7s: train loss = 0.09883 = (mf)0.09167 + (embed)0.00716
# Epoch 28 (train)6.4s: train loss = 0.09467 = (mf)0.08726 + (embed)0.00741
# Epoch 29 (train)7.7s: train loss = 0.09353 = (mf)0.08588 + (embed)0.00765
# Save model to path /content/model_checkpoints/config4/epoch_30
# Epoch 30 (train)6.4s + (eval)0.6s: train loss = 0.09315 = (mf)0.08527 + (embed)0.00789, map = 0.30737, ndcg = 0.45259, precision = 0.39502, recall = 0.21414
# Epoch 31 (train)7.6s: train loss = 0.09089 = (mf)0.08276 + (embed)0.00813
# Epoch 32 (train)6.5s: train loss = 0.08627 = (mf)0.07791 + (embed)0.00836
# Epoch 33 (train)7.5s: train loss = 0.08641 = (mf)0.07779 + (embed)0.00862
# Epoch 34 (train)6.5s: train loss = 0.08367 = (mf)0.07484 + (embed)0.00883
# Save model to path /content/model_checkpoints/config4/epoch_35
# Epoch 35 (train)7.5s + (eval)0.3s: train loss = 0.08282 = (mf)0.07374 + (embed)0.00907, map = 0.30545, ndcg = 0.44932, precision = 0.39608, recall = 0.21387
# Epoch 36 (train)6.7s: train loss = 0.08165 = (mf)0.07233 + (embed)0.00932
# Epoch 37 (train)7.3s: train loss = 0.08058 = (mf)0.07102 + (embed)0.00956
# Epoch 38 (train)6.8s: train loss = 0.07906 = (mf)0.06929 + (embed)0.00977
# Epoch 39 (train)7.3s: train loss = 0.07755 = (mf)0.06756 + (embed)0.00999
# Save model to path /content/model_checkpoints/config4/epoch_40
# Epoch 40 (train)6.9s + (eval)0.8s: train loss = 0.07607 = (mf)0.06586 + (embed)0.01020, map = 0.29865, ndcg = 0.44220, precision = 0.38834, recall = 0.20967
# Epoch 41 (train)6.9s: train loss = 0.07580 = (mf)0.06538 + (embed)0.01042
# Epoch 42 (train)7.2s: train loss = 0.07550 = (mf)0.06488 + (embed)0.01062
# Epoch 43 (train)6.8s: train loss = 0.07356 = (mf)0.06273 + (embed)0.01083
# Epoch 44 (train)7.2s: train loss = 0.07153 = (mf)0.06050 + (embed)0.01103
# Save model to path /content/model_checkpoints/config4/epoch_45
# Epoch 45 (train)6.9s + (eval)0.3s: train loss = 0.07066 = (mf)0.05943 + (embed)0.01123, map = 0.30298, ndcg = 0.44734, precision = 0.39385, recall = 0.21390
# Epoch 46 (train)7.4s: train loss = 0.06865 = (mf)0.05723 + (embed)0.01143
# Epoch 47 (train)6.6s: train loss = 0.06929 = (mf)0.05768 + (embed)0.01161
# Epoch 48 (train)7.5s: train loss = 0.06876 = (mf)0.05696 + (embed)0.01180
# Epoch 49 (train)6.6s: train loss = 0.06803 = (mf)0.05603 + (embed)0.01200
# Save model to path /content/model_checkpoints/config4/epoch_50
# Epoch 50 (train)7.5s + (eval)0.6s: train loss = 0.06623 = (mf)0.05407 + (embed)0.01216, map = 0.29277, ndcg = 0.43825, precision = 0.38409, recall = 0.20915
# Epoch 51 (train)6.7s: train loss = 0.06663 = (mf)0.05429 + (embed)0.01234
# Epoch 52 (train)8.7s: train loss = 0.06449 = (mf)0.05199 + (embed)0.01250
# Epoch 53 (train)6.4s: train loss = 0.06551 = (mf)0.05284 + (embed)0.01267
# Epoch 54 (train)7.6s: train loss = 0.06488 = (mf)0.05205 + (embed)0.01283
# Save model to path /content/model_checkpoints/config4/epoch_55
# Epoch 55 (train)6.4s + (eval)0.3s: train loss = 0.06253 = (mf)0.04952 + (embed)0.01301, map = 0.28314, ndcg = 0.42704, precision = 0.37540, recall = 0.20438
# Epoch 56 (train)7.6s: train loss = 0.06330 = (mf)0.05013 + (embed)0.01317
# Epoch 57 (train)6.4s: train loss = 0.06207 = (mf)0.04875 + (embed)0.01332
# Epoch 58 (train)7.7s: train loss = 0.06214 = (mf)0.04867 + (embed)0.01346
# Epoch 59 (train)6.3s: train loss = 0.06171 = (mf)0.04809 + (embed)0.01362
# Save model to path /content/model_checkpoints/config4/epoch_60
# Epoch 60 (train)7.7s + (eval)0.3s: train loss = 0.06023 = (mf)0.04646 + (embed)0.01377, map = 0.27913, ndcg = 0.42237, precision = 0.37200, recall = 0.20242
# Epoch 61 (train)6.4s: train loss = 0.05961 = (mf)0.04569 + (embed)0.01392
# Epoch 62 (train)7.6s: train loss = 0.05940 = (mf)0.04535 + (embed)0.01405
# Epoch 63 (train)6.3s: train loss = 0.05976 = (mf)0.04557 + (embed)0.01420
# Epoch 64 (train)7.7s: train loss = 0.05817 = (mf)0.04386 + (embed)0.01431
# Save model to path /content/model_checkpoints/config4/epoch_65
# Epoch 65 (train)6.4s + (eval)0.7s: train loss = 0.05788 = (mf)0.04345 + (embed)0.01443, map = 0.26816, ndcg = 0.40997, precision = 0.35790, recall = 0.19715
# Epoch 66 (train)7.6s: train loss = 0.05783 = (mf)0.04327 + (embed)0.01456
# Epoch 67 (train)6.5s: train loss = 0.05820 = (mf)0.04353 + (embed)0.01467
# Epoch 68 (train)7.5s: train loss = 0.05780 = (mf)0.04302 + (embed)0.01478
# Epoch 69 (train)6.6s: train loss = 0.05651 = (mf)0.04161 + (embed)0.01490
# Save model to path /content/model_checkpoints/config4/epoch_70
# Epoch 70 (train)7.5s + (eval)0.3s: train loss = 0.05682 = (mf)0.04180 + (embed)0.01502, map = 0.26303, ndcg = 0.40511, precision = 0.35493, recall = 0.19580
# Epoch 71 (train)6.7s: train loss = 0.05557 = (mf)0.04043 + (embed)0.01514
# Epoch 72 (train)7.3s: train loss = 0.05750 = (mf)0.04223 + (embed)0.01527
# Epoch 73 (train)6.7s: train loss = 0.05633 = (mf)0.04096 + (embed)0.01537
# Epoch 74 (train)7.3s: train loss = 0.05454 = (mf)0.03906 + (embed)0.01548
# Save model to path /content/model_checkpoints/config4/epoch_75
# Epoch 75 (train)6.8s + (eval)0.8s: train loss = 0.05467 = (mf)0.03912 + (embed)0.01555, map = 0.26350, ndcg = 0.40586, precision = 0.35567, recall = 0.19505
# Epoch 76 (train)6.9s: train loss = 0.05523 = (mf)0.03955 + (embed)0.01567
# Epoch 77 (train)7.1s: train loss = 0.05369 = (mf)0.03791 + (embed)0.01578
# Epoch 78 (train)6.9s: train loss = 0.05455 = (mf)0.03870 + (embed)0.01585
# Epoch 79 (train)7.3s: train loss = 0.05362 = (mf)0.03766 + (embed)0.01596
# Save model to path /content/model_checkpoints/config4/epoch_80
# Epoch 80 (train)6.7s + (eval)0.3s: train loss = 0.05389 = (mf)0.03785 + (embed)0.01604, map = 0.25576, ndcg = 0.39776, precision = 0.34857, recall = 0.19007
# Epoch 81 (train)7.4s: train loss = 0.05358 = (mf)0.03744 + (embed)0.01614
# Epoch 82 (train)6.6s: train loss = 0.05355 = (mf)0.03731 + (embed)0.01624
# Epoch 83 (train)9.1s: train loss = 0.05340 = (mf)0.03709 + (embed)0.01630
# Epoch 84 (train)6.3s: train loss = 0.05371 = (mf)0.03730 + (embed)0.01641
# Save model to path /content/model_checkpoints/config4/epoch_85
# Epoch 85 (train)7.7s + (eval)0.6s: train loss = 0.05169 = (mf)0.03521 + (embed)0.01648, map = 0.25187, ndcg = 0.39291, precision = 0.34571, recall = 0.18917
# Epoch 86 (train)6.3s: train loss = 0.05145 = (mf)0.03486 + (embed)0.01659
# Epoch 87 (train)7.7s: train loss = 0.05120 = (mf)0.03454 + (embed)0.01667
# Epoch 88 (train)6.3s: train loss = 0.05207 = (mf)0.03534 + (embed)0.01672
# Epoch 89 (train)7.6s: train loss = 0.05118 = (mf)0.03440 + (embed)0.01679
# Save model to path /content/model_checkpoints/config4/epoch_90
# Epoch 90 (train)6.4s + (eval)0.3s: train loss = 0.05099 = (mf)0.03409 + (embed)0.01690, map = 0.24934, ndcg = 0.39199, precision = 0.34560, recall = 0.19101
# Epoch 91 (train)7.6s: train loss = 0.05138 = (mf)0.03440 + (embed)0.01698
# Epoch 92 (train)6.3s: train loss = 0.05077 = (mf)0.03373 + (embed)0.01704
# Epoch 93 (train)7.6s: train loss = 0.05086 = (mf)0.03373 + (embed)0.01713
# Epoch 94 (train)6.3s: train loss = 0.05056 = (mf)0.03339 + (embed)0.01717
# Save model to path /content/model_checkpoints/config4/epoch_95
# Epoch 95 (train)7.7s + (eval)0.6s: train loss = 0.05023 = (mf)0.03298 + (embed)0.01725, map = 0.24136, ndcg = 0.38460, precision = 0.33945, recall = 0.18874
# Epoch 96 (train)6.3s: train loss = 0.04956 = (mf)0.03221 + (embed)0.01734
# Epoch 97 (train)7.7s: train loss = 0.05120 = (mf)0.03380 + (embed)0.01740
# Epoch 98 (train)6.3s: train loss = 0.04899 = (mf)0.03153 + (embed)0.01745
# Epoch 99 (train)7.7s: train loss = 0.04929 = (mf)0.03178 + (embed)0.01750
# Save model to path /content/model_checkpoints/config4/epoch_100
# Epoch 100 (train)6.4s + (eval)0.3s: train loss = 0.04894 = (mf)0.03136 + (embed)0.01759, map = 0.24854, ndcg = 0.39321, precision = 0.34655, recall = 0.19262
# Training completed in 718.98 seconds
# Evaluation Metrics:
# MAP@10: 0.1153
# NDCG@10: 0.3932
# Precision@10: 0.3466
# Recall@10: 0.1926
# Interim results saved to '/content/drive/MyDrive/lightgcn_results/lightgcn_evaluation_interim.csv'
#
# Results saved to '/content/drive/MyDrive/lightgcn_results/lightgcn_evaluation_results.csv'
#
# Summary of Results:
#   config_name  epochs  batch_size       map      ndcg  precision    recall  \
# 0     config1      50        1024  0.139610  0.458353   0.399576  0.216312
# 1     config2      50         256  0.129929  0.433855   0.379639  0.208013
# 2     config3     100        1024  0.130360  0.436666   0.385684  0.209662
# 3     config4     100         256  0.115269  0.393208   0.346554  0.192624
#
#    training_time
# 0     127.118077
# 1     361.846689
# 2     233.892473
# 3     718.983322

# %%
# Cold-Start Analysis for LightGCN
import pandas as pd
import numpy as np
import tensorflow as tf
import yaml
import time
from collections import defaultdict
import matplotlib.pyplot as plt
import gc

# Install necessary packages for Colab
# !pip install recommenders psutil

# Fix NumPy deprecated function issue
from recommenders.models.deeprec.models.graphrec.lightgcn import LightGCN
original_convert_sp_mat = LightGCN._convert_sp_mat_to_sp_tensor

def patched_convert_sp_mat(self, X):
    """Patch to replace np.mat with proper NumPy 2.0 compatible code"""
    coo = X.tocoo().astype(np.float32)
    indices = np.array([coo.row, coo.col]).transpose()
    return tf.SparseTensor(indices, coo.data, coo.shape)

# Apply the patch
LightGCN._convert_sp_mat_to_sp_tensor = patched_convert_sp_mat

# Import required modules
from recommenders.utils.timer import Timer
from recommenders.models.deeprec.DataModel.ImplicitCF import ImplicitCF
from recommenders.datasets import movielens
from recommenders.datasets.python_splitters import python_stratified_split
from recommenders.evaluation.python_evaluation import map, ndcg_at_k, precision_at_k, recall_at_k
from recommenders.utils.constants import SEED as DEFAULT_SEED
from recommenders.models.deeprec.deeprec_utils import prepare_hparams
import psutil

# Create Google Drive mount point to save results
from google.colab import drive
drive.mount('/content/drive')

# Define paths for saving results
RESULTS_DIR = '/content/drive/MyDrive/lightgcn_results'
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs('recommenders/models/deeprec/config', exist_ok=True)
os.makedirs('model_checkpoints', exist_ok=True)

# Constants
MOVIELENS_DATA_SIZE = '100k'
TOP_K = 10
SEED = DEFAULT_SEED
BATCH_SIZE = 1024
EPOCHS = 50

def reset_tf_graph():
    """Reset TensorFlow graph in a way that works with both TF 1.x and 2.x"""
    if hasattr(tf, 'reset_default_graph'):
        # TensorFlow 1.x
        tf.reset_default_graph()
    else:
        # TensorFlow 2.x - create a new graph and set as default
        tf.compat.v1.reset_default_graph()

def create_yaml_config(config_name, epochs, batch_size):
    """Create YAML config file for LightGCN."""
    yaml_config = {
        'model': {
            'name': 'lightgcn',
            'model_type': 'graphrec',
            'user_embedding_size': 64,
            'item_embedding_size': 64,
            'embed_size': 64,
            'n_layers': 3,
            'batch_size': batch_size,
            'show_step': 1,
            'learning_rate': 0.005,
            'epochs': epochs,
            'eval_epoch': 5,
            'top_k': TOP_K
        },
        'train': {
            'batch_size': batch_size,
            'epochs': epochs,
            'learning_rate': 0.005
        },
        'evaluate': {
            'metrics': ['map', 'ndcg', 'precision', 'recall'],
            'cutoffs': [10, 20],
            'k': 10
        }
    }

    yaml_file_path = f'recommenders/models/deeprec/config/lightgcn_{config_name}.yaml'
    with open(yaml_file_path, 'w') as f:
        yaml.dump(yaml_config, f)

    return yaml_file_path

def count_interactions(df, column_name):
    """Count interactions per user/item"""
    return df.groupby(column_name).size()

def create_interaction_buckets(counts, num_buckets=5):
    """Create buckets based on number of interactions"""
    # Get quantiles to create roughly equal-sized buckets
    quantiles = np.linspace(0, 1, num_buckets + 1)[1:-1]
    thresholds = [1] + [int(t) for t in np.quantile(counts, quantiles)] + [float('inf')]

    # Create buckets
    buckets = {}
    for i in range(len(thresholds) - 1):
        min_val = thresholds[i]
        max_val = thresholds[i+1]
        if min_val == max_val:
            bucket_name = f"{min_val}"
        else:
            bucket_name = f"{min_val}-{max_val-1}" if max_val != float('inf') else f"{min_val}+"

        buckets[bucket_name] = [id for id, count in counts.items()
                               if min_val <= count < max_val]

    print("Interaction buckets:")
    for bucket, ids in buckets.items():
        print(f"  {bucket}: {len(ids)} entities")

    return buckets

def evaluate_cold_start(model, test_df, buckets, entity_type, metrics, k=10):
    """Evaluate model performance on different cold-start buckets"""
    results = {}

    for bucket, ids in buckets.items():
        print(f"Evaluating {entity_type} bucket: {bucket}")

        # Filter test data based on bucket
        if entity_type == 'user':
            bucket_test = test_df[test_df['userID'].isin(ids)]
        else:  # item
            bucket_test = test_df[test_df['itemID'].isin(ids)]

        if len(bucket_test) == 0:
            print(f"  No test data for {entity_type} bucket {bucket}, skipping")
            continue

        # Get recommendations for filtered test data
        topk_scores = model.recommend_k_items(bucket_test, top_k=k, remove_seen=True)

        # Calculate metrics
        bucket_results = {}
        bucket_results['count'] = len(bucket_test)
        bucket_results['map'] = map(bucket_test, topk_scores, k=k)
        bucket_results['ndcg'] = ndcg_at_k(bucket_test, topk_scores, k=k)
        bucket_results['precision'] = precision_at_k(bucket_test, topk_scores, k=k)
        bucket_results['recall'] = recall_at_k(bucket_test, topk_scores, k=k)

        results[bucket] = bucket_results
        print(f"  MAP: {bucket_results['map']:.4f}, NDCG: {bucket_results['ndcg']:.4f}")

    return results

def main():
    # Load data
    print("Loading MovieLens data...")
    df = movielens.load_pandas_df(size=MOVIELENS_DATA_SIZE)
    print("MovieLens data loaded successfully")

    # Count interactions per user and item
    user_counts = count_interactions(df, 'userID')
    item_counts = count_interactions(df, 'itemID')

    print(f"User interaction statistics:")
    print(f"  Min: {user_counts.min()}, Max: {user_counts.max()}, Median: {user_counts.median():.1f}, Mean: {user_counts.mean():.1f}")
    print(f"Item interaction statistics:")
    print(f"  Min: {item_counts.min()}, Max: {item_counts.max()}, Median: {item_counts.median():.1f}, Mean: {item_counts.mean():.1f}")

    # Create buckets based on interaction counts
    user_buckets = create_interaction_buckets(user_counts)
    item_buckets = create_interaction_buckets(item_counts)

    # Split data into train and test
    train, test = python_stratified_split(df, ratio=0.75)
    print(f"Train set size: {len(train)}, Test set size: {len(test)}")

    # Prepare data model
    data = ImplicitCF(train=train, test=test, seed=SEED)

    # Create config file
    yaml_file = create_yaml_config('cold_start', EPOCHS, BATCH_SIZE)

    # Prepare hyperparameters
    hparams = prepare_hparams(
        yaml_file,
        n_layers=3,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        learning_rate=0.005,
        eval_epoch=5,
        top_k=TOP_K,
        decay=0.0001,
        save_epoch=5,
        metrics=['map', 'ndcg', 'precision', 'recall'],
        MODEL_DIR='model_checkpoints/cold_start'
    )

    # Train model
    try:
        print("Initializing and training model...")
        model = LightGCN(hparams, data)

        with Timer() as train_time:
            model.fit()

        print(f"Training completed in {train_time.interval:.2f} seconds")

        # Perform cold-start analysis
        print("\nPerforming cold-start analysis...")
        metrics = ['map', 'ndcg', 'precision', 'recall']

        # Cold-start user analysis
        print("\nCold-start USER analysis:")
        user_results = evaluate_cold_start(model, test, user_buckets, 'user', metrics, k=TOP_K)

        # Cold-start item analysis
        print("\nCold-start ITEM analysis:")
        item_results = evaluate_cold_start(model, test, item_buckets, 'item', metrics, k=TOP_K)

        # Convert results to DataFrames for easier analysis
        user_df = pd.DataFrame.from_dict(user_results, orient='index')
        item_df = pd.DataFrame.from_dict(item_results, orient='index')

        # Save results
        user_df.to_csv(f'{RESULTS_DIR}/cold_start_user_analysis.csv')
        item_df.to_csv(f'{RESULTS_DIR}/cold_start_item_analysis.csv')

        print(f"\nCold-start user analysis results:")
        print(user_df)
        print(f"\nCold-start item analysis results:")
        print(item_df)

        # Aggregate results for reporting
        print("\nCold-start Performance Summary:")
        print("User interaction level impact on performance:")
        for metric in ['map', 'ndcg', 'precision', 'recall']:
            print(f"  {metric.upper()}: {' | '.join([f'{bucket}: {row[metric]:.4f}' for bucket, row in user_df.iterrows()])}")

        print("\nItem interaction level impact on performance:")
        for metric in ['map', 'ndcg', 'precision', 'recall']:
            print(f"  {metric.upper()}: {' | '.join([f'{bucket}: {row[metric]:.4f}' for bucket, row in item_df.iterrows()])}")

        # Clean up
        del model
        reset_tf_graph()
        gc.collect()

    except Exception as e:
        print(f"Error during cold-start analysis: {str(e)}")
        try:
            reset_tf_graph()
        except:
            print("Failed to reset TensorFlow graph.")
        gc.collect()

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: recommenders in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (5.9.5)
# Requirement already satisfied: category-encoders<3,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (2.8.1)
# Requirement already satisfied: cornac<3,>=1.15.2 in /usr/local/lib/python3.11/dist-packages (from recommenders) (2.3.3)
# Requirement already satisfied: hyperopt<1,>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.2.7)
# Requirement already satisfied: lightgbm<5,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (4.5.0)
# Requirement already satisfied: locust<3,>=2.12.2 in /usr/local/lib/python3.11/dist-packages (from recommenders) (2.37.1)
# Requirement already satisfied: memory-profiler<1,>=0.61.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.61.0)
# Requirement already satisfied: nltk<4,>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from recommenders) (3.9.1)
# Requirement already satisfied: notebook<8,>=6.5.5 in /usr/local/lib/python3.11/dist-packages (from recommenders) (6.5.7)
# Requirement already satisfied: numba<1,>=0.57.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.60.0)
# Requirement already satisfied: pandas<3.0.0,>2.0.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (2.2.2)
# Requirement already satisfied: retrying<2,>=1.3.4 in /usr/local/lib/python3.11/dist-packages (from recommenders) (1.3.4)
# Requirement already satisfied: scikit-learn<2,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (1.6.1)
# Requirement already satisfied: scikit-surprise>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from recommenders) (1.1.4)
# Requirement already satisfied: seaborn<1,>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.13.2)
# Requirement already satisfied: transformers<5,>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from recommenders) (4.51.3)
# Requirement already satisfied: pandera>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.23.1)
# Requirement already satisfied: statsmodels>=0.14.4 in /usr/local/lib/python3.11/dist-packages (from recommenders) (0.14.4)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from category-encoders<3,>=2.6.0->recommenders) (2.0.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category-encoders<3,>=2.6.0->recommenders) (1.0.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from category-encoders<3,>=2.6.0->recommenders) (1.15.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from cornac<3,>=1.15.2->recommenders) (4.67.1)
# Requirement already satisfied: powerlaw in /usr/local/lib/python3.11/dist-packages (from cornac<3,>=1.15.2->recommenders) (1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (1.17.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (3.4.2)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (1.0.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (3.1.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.11/dist-packages (from hyperopt<1,>=0.2.7->recommenders) (0.10.9.7)
# Requirement already satisfied: configargparse>=1.5.5 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (1.7)
# Requirement already satisfied: flask-cors>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (5.0.1)
# Requirement already satisfied: flask-login>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (0.6.3)
# Requirement already satisfied: flask>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (3.1.0)
# Requirement already satisfied: gevent<25.0.0,>=24.10.1 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (24.11.1)
# Requirement already satisfied: geventhttpclient>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (2.3.3)
# Requirement already satisfied: locust-cloud>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (1.21.3)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (26.4.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (2.32.3)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (75.2.0)
# Requirement already satisfied: werkzeug>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from locust<3,>=2.12.2->recommenders) (3.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk<4,>=3.8.1->recommenders) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk<4,>=3.8.1->recommenders) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk<4,>=3.8.1->recommenders) (2024.11.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (6.4.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (5.7.2)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook<8,>=6.5.5->recommenders) (1.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba<1,>=0.57.0->recommenders) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>2.0.0->recommenders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>2.0.0->recommenders) (2025.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (24.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.11.4)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.11/dist-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (4.4.2)
# Requirement already satisfied: typing_inspect>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.9.0)
# Requirement already satisfied: hypothesis>=6.92.7 in /usr/local/lib/python3.11/dist-packages (from pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (6.131.15)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2,>=1.2.0->recommenders) (3.6.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn<1,>=0.13.0->recommenders) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (0.30.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5,>=4.27.0->recommenders) (0.5.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.0->locust<3,>=2.12.2->recommenders) (1.9.0)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.11/dist-packages (from gevent<25.0.0,>=24.10.1->locust<3,>=2.12.2->recommenders) (5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.11/dist-packages (from gevent<25.0.0,>=24.10.1->locust<3,>=2.12.2->recommenders) (7.2)
# Requirement already satisfied: greenlet>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from gevent<25.0.0,>=24.10.1->locust<3,>=2.12.2->recommenders) (3.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (2025.4.26)
# Requirement already satisfied: brotli in /usr/local/lib/python3.11/dist-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from geventhttpclient>=2.3.1->locust<3,>=2.12.2->recommenders) (2.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers<5,>=4.27.0->recommenders) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers<5,>=4.27.0->recommenders) (4.13.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (25.3.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from hypothesis>=6.92.7->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->notebook<8,>=6.5.5->recommenders) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.1->notebook<8,>=6.5.5->recommenders) (4.3.7)
# Requirement already satisfied: python-socketio==5.13.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (5.13.0)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (4.12.0)
# Requirement already satisfied: websocket-client>=0.54.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn<1,>=0.13.0->recommenders) (3.2.3)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook<8,>=6.5.5->recommenders) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook<8,>=6.5.5->recommenders) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook<8,>=6.5.5->recommenders) (2.19.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook<8,>=6.5.5->recommenders) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook<8,>=6.5.5->recommenders) (4.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->locust<3,>=2.12.2->recommenders) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->locust<3,>=2.12.2->recommenders) (3.10)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->notebook<8,>=6.5.5->recommenders) (0.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing_inspect>=0.6.0->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (1.1.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook<8,>=6.5.5->recommenders) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook<8,>=6.5.5->recommenders) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook<8,>=6.5.5->recommenders) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->notebook<8,>=6.5.5->recommenders) (0.1.7)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.11/dist-packages (from powerlaw->cornac<3,>=1.15.2->recommenders) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->pandera>=0.15.0->pandera[strategies]>=0.15.0; python_version >= "3.9"->recommenders) (0.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook<8,>=6.5.5->recommenders) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook<8,>=6.5.5->recommenders) (1.4.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook<8,>=6.5.5->recommenders) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook<8,>=6.5.5->recommenders) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook<8,>=6.5.5->recommenders) (0.24.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook<8,>=6.5.5->recommenders) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook<8,>=6.5.5->recommenders) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook<8,>=6.5.5->recommenders) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook<8,>=6.5.5->recommenders) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.8.4)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook<8,>=6.5.5->recommenders) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook<8,>=6.5.5->recommenders) (0.2.13)
# Requirement already satisfied: simple-websocket>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from python-engineio>=4.11.0->python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook<8,>=6.5.5->recommenders) (1.3.1)
# Requirement already satisfied: wsproto in /usr/local/lib/python3.11/dist-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (1.2.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio==5.13.0->python-socketio[client]==5.13.0->locust-cloud>=1.21.2->locust<3,>=2.12.2->recommenders) (0.16.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading MovieLens data...
# 100%|██████████| 4.81k/4.81k [00:00<00:00, 11.6kKB/s]
# MovieLens data loaded successfully
# User interaction statistics:
#   Min: 20, Max: 737, Median: 65.0, Mean: 106.0
# Item interaction statistics:
#   Min: 1, Max: 583, Median: 27.0, Mean: 59.5
# Interaction buckets:
#   1-28: 187 entities
#   29-49: 188 entities
#   50-92: 187 entities
#   93-170: 190 entities
#   171+: 191 entities
# Interaction buckets:
#   1-4: 333 entities
#   5-15: 339 entities
#   16-42: 332 entities
#   43-99: 340 entities
#   100+: 338 entities
# Train set size: 74992, Test set size: 25008
# Initializing and training model...
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.
# Epoch 1 (train)2.2s: train loss = 0.47168 = (mf)0.47143 + (embed)0.00024
# Epoch 2 (train)2.0s: train loss = 0.29010 = (mf)0.28947 + (embed)0.00063
# Epoch 3 (train)2.0s: train loss = 0.25365 = (mf)0.25286 + (embed)0.00079
# Epoch 4 (train)2.0s: train loss = 0.23849 = (mf)0.23752 + (embed)0.00097
# Save model to path /content/model_checkpoints/cold_start/epoch_5
# Epoch 5 (train)3.1s + (eval)0.5s: train loss = 0.22635 = (mf)0.22525 + (embed)0.00111, map = 0.21589, ndcg = 0.34528, precision = 0.29873, recall = 0.15604
# Epoch 6 (train)2.3s: train loss = 0.21993 = (mf)0.21872 + (embed)0.00122
# Epoch 7 (train)2.0s: train loss = 0.21247 = (mf)0.21115 + (embed)0.00133
# Epoch 8 (train)2.0s: train loss = 0.20166 = (mf)0.20020 + (embed)0.00146
# Epoch 9 (train)2.0s: train loss = 0.18961 = (mf)0.18799 + (embed)0.00162
# Save model to path /content/model_checkpoints/cold_start/epoch_10
# Epoch 10 (train)2.0s + (eval)0.6s: train loss = 0.18167 = (mf)0.17989 + (embed)0.00179, map = 0.25166, ndcg = 0.38822, precision = 0.33934, recall = 0.17587
# Epoch 11 (train)3.1s: train loss = 0.17129 = (mf)0.16935 + (embed)0.00194
# Epoch 12 (train)2.3s: train loss = 0.16968 = (mf)0.16759 + (embed)0.00209
# Epoch 13 (train)2.0s: train loss = 0.16617 = (mf)0.16396 + (embed)0.00221
# Epoch 14 (train)2.0s: train loss = 0.16545 = (mf)0.16313 + (embed)0.00232
# Save model to path /content/model_checkpoints/cold_start/epoch_15
# Epoch 15 (train)2.0s + (eval)0.2s: train loss = 0.16116 = (mf)0.15875 + (embed)0.00241, map = 0.26510, ndcg = 0.40379, precision = 0.35090, recall = 0.18458
# Epoch 16 (train)2.0s: train loss = 0.16134 = (mf)0.15882 + (embed)0.00251
# Epoch 17 (train)3.0s: train loss = 0.15985 = (mf)0.15725 + (embed)0.00260
# Epoch 18 (train)2.5s: train loss = 0.15368 = (mf)0.15099 + (embed)0.00269
# Epoch 19 (train)2.0s: train loss = 0.15133 = (mf)0.14853 + (embed)0.00280
# Save model to path /content/model_checkpoints/cold_start/epoch_20
# Epoch 20 (train)2.0s + (eval)0.3s: train loss = 0.15087 = (mf)0.14798 + (embed)0.00288, map = 0.27083, ndcg = 0.41081, precision = 0.35737, recall = 0.18917
# Epoch 21 (train)2.0s: train loss = 0.14900 = (mf)0.14603 + (embed)0.00298
# Epoch 22 (train)2.0s: train loss = 0.14541 = (mf)0.14232 + (embed)0.00309
# Epoch 23 (train)2.9s: train loss = 0.14408 = (mf)0.14089 + (embed)0.00320
# Epoch 24 (train)2.6s: train loss = 0.13858 = (mf)0.13528 + (embed)0.00330
# Save model to path /content/model_checkpoints/cold_start/epoch_25
# Epoch 25 (train)2.0s + (eval)0.5s: train loss = 0.13870 = (mf)0.13528 + (embed)0.00342, map = 0.28242, ndcg = 0.42342, precision = 0.36978, recall = 0.19689
# Epoch 26 (train)2.0s: train loss = 0.13670 = (mf)0.13317 + (embed)0.00354
# Epoch 27 (train)2.0s: train loss = 0.13430 = (mf)0.13065 + (embed)0.00365
# Epoch 28 (train)2.5s: train loss = 0.13218 = (mf)0.12842 + (embed)0.00376
# Epoch 29 (train)3.5s: train loss = 0.13249 = (mf)0.12863 + (embed)0.00386
# Save model to path /content/model_checkpoints/cold_start/epoch_30
# Epoch 30 (train)2.3s + (eval)0.2s: train loss = 0.12881 = (mf)0.12482 + (embed)0.00399, map = 0.29477, ndcg = 0.43656, precision = 0.37985, recall = 0.20238
# Epoch 31 (train)2.0s: train loss = 0.12755 = (mf)0.12346 + (embed)0.00409
# Epoch 32 (train)2.2s: train loss = 0.12605 = (mf)0.12183 + (embed)0.00422
# Epoch 33 (train)2.4s: train loss = 0.12559 = (mf)0.12126 + (embed)0.00433
# Epoch 34 (train)2.3s: train loss = 0.12141 = (mf)0.11696 + (embed)0.00445
# Save model to path /content/model_checkpoints/cold_start/epoch_35
# Epoch 35 (train)3.1s + (eval)0.6s: train loss = 0.12109 = (mf)0.11653 + (embed)0.00457, map = 0.29790, ndcg = 0.43974, precision = 0.38420, recall = 0.20451
# Epoch 36 (train)2.0s: train loss = 0.11732 = (mf)0.11263 + (embed)0.00469
# Epoch 37 (train)2.0s: train loss = 0.11915 = (mf)0.11435 + (embed)0.00480
# Epoch 38 (train)2.0s: train loss = 0.11773 = (mf)0.11282 + (embed)0.00492
# Epoch 39 (train)2.0s: train loss = 0.11122 = (mf)0.10616 + (embed)0.00506
# Save model to path /content/model_checkpoints/cold_start/epoch_40
# Epoch 40 (train)2.2s + (eval)0.4s: train loss = 0.11425 = (mf)0.10907 + (embed)0.00518, map = 0.30428, ndcg = 0.44706, precision = 0.38929, recall = 0.20962
# Epoch 41 (train)3.1s: train loss = 0.11097 = (mf)0.10567 + (embed)0.00530
# Epoch 42 (train)2.0s: train loss = 0.10831 = (mf)0.10287 + (embed)0.00544
# Epoch 43 (train)2.0s: train loss = 0.10932 = (mf)0.10376 + (embed)0.00555
# Epoch 44 (train)2.0s: train loss = 0.10470 = (mf)0.09902 + (embed)0.00568
# Save model to path /content/model_checkpoints/cold_start/epoch_45
# Epoch 45 (train)2.0s + (eval)0.5s: train loss = 0.10536 = (mf)0.09955 + (embed)0.00581, map = 0.30951, ndcg = 0.45333, precision = 0.39406, recall = 0.21075
# Epoch 46 (train)2.4s: train loss = 0.10619 = (mf)0.10026 + (embed)0.00593
# Epoch 47 (train)3.1s: train loss = 0.10427 = (mf)0.09821 + (embed)0.00605
# Epoch 48 (train)2.0s: train loss = 0.10272 = (mf)0.09654 + (embed)0.00618
# Epoch 49 (train)2.0s: train loss = 0.09851 = (mf)0.09219 + (embed)0.00632
# Save model to path /content/model_checkpoints/cold_start/epoch_50
# Epoch 50 (train)2.8s + (eval)0.6s: train loss = 0.09715 = (mf)0.09070 + (embed)0.00645, map = 0.31335, ndcg = 0.45835, precision = 0.39958, recall = 0.21631
# Training completed in 118.92 seconds
#
# Performing cold-start analysis...
#
# Cold-start USER analysis:
# Evaluating user bucket: 1-28
#   MAP: 0.1917, NDCG: 0.3284
# Evaluating user bucket: 29-49
#   MAP: 0.1590, NDCG: 0.3056
# Evaluating user bucket: 50-92
#   MAP: 0.1400, NDCG: 0.3875
# Evaluating user bucket: 93-170
#   MAP: 0.1177, NDCG: 0.5396
# Evaluating user bucket: 171+
#   MAP: 0.0909, NDCG: 0.7244
#
# Cold-start ITEM analysis:
# Evaluating item bucket: 1-4
#   MAP: 0.0000, NDCG: 0.0000
# Evaluating item bucket: 5-15
#   MAP: 0.0004, NDCG: 0.0012
# Evaluating item bucket: 16-42
#   MAP: 0.0034, NDCG: 0.0084
# Evaluating item bucket: 43-99
#   MAP: 0.0097, NDCG: 0.0261
# Evaluating item bucket: 100+
#   MAP: 0.1852, NDCG: 0.4644
#
# Cold-start user analysis results:
#         count       map      ndcg  precision    recall
# 1-28     1097  0.191702  0.328406   0.198396  0.338732
# 29-49    1792  0.159020  0.305600   0.254787  0.268994
# 50-92    3080  0.140017  0.387543   0.348128  0.213258
# 93-170   6068  0.117687  0.539649   0.491053  0.155491
# 171+    12971  0.090915  0.724392   0.698429  0.108097
#
# Cold-start item analysis results:
#        count       map      ndcg  precision    recall
# 1-4      168  0.000000  0.000000   0.000000  0.000000
# 5-15     762  0.000381  0.001214   0.000888  0.001775
# 16-42   2258  0.003415  0.008409   0.005085  0.015176
# 43-99   5678  0.009744  0.026110   0.019658  0.035027
# 100+   16142  0.185151  0.464409   0.379406  0.288288
#
# Cold-start Performance Summary:
# User interaction level impact on performance:
#   MAP: 1-28: 0.1917 | 29-49: 0.1590 | 50-92: 0.1400 | 93-170: 0.1177 | 171+: 0.0909
#   NDCG: 1-28: 0.3284 | 29-49: 0.3056 | 50-92: 0.3875 | 93-170: 0.5396 | 171+: 0.7244
#   PRECISION: 1-28: 0.1984 | 29-49: 0.2548 | 50-92: 0.3481 | 93-170: 0.4911 | 171+: 0.6984
#   RECALL: 1-28: 0.3387 | 29-49: 0.2690 | 50-92: 0.2133 | 93-170: 0.1555 | 171+: 0.1081
#
# Item interaction level impact on performance:
#   MAP: 1-4: 0.0000 | 5-15: 0.0004 | 16-42: 0.0034 | 43-99: 0.0097 | 100+: 0.1852
#   NDCG: 1-4: 0.0000 | 5-15: 0.0012 | 16-42: 0.0084 | 43-99: 0.0261 | 100+: 0.4644
#   PRECISION: 1-4: 0.0000 | 5-15: 0.0009 | 16-42: 0.0051 | 43-99: 0.0197 | 100+: 0.3794
#   RECALL: 1-4: 0.0000 | 5-15: 0.0018 | 16-42: 0.0152 | 43-99: 0.0350 | 100+: 0.2883
